# %% [markdown]
# Useful for scraping pages with unique data for scraper.build such as title vs other texts, links etc...

# %% [markdown]
# ### Autoscrapper

# %%
pip install autoscraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from autoscraper import AutoScraper

# %%
url = 'https://ww2.3hiidude.me/watch-reefa-2021-english-full-movie-online-free-5953.html'
wanted_list = ['Reefa (2021) HDRip English Full Movie Watch Online Free',
                '2.5/5',
               'Drama,']
#     'Genres: Action, Adventure, Fantasy,',
#     'Rating : 2.5'
              

scraper = AutoScraper()
result = scraper.build(url, wanted_list)
# print(result)
result = scraper.get_result_similar('https://ww2.3hiidude.me/watch-trigger-point-2021-english-full-movie-online-free-5934.html', grouped=True)
print(result)
# Out:
# {'rule_d0or': ['Trigger Point (2021) DVDScr English Full Movie Watch Online Free'], 'rule_h5kq': ['2.5/5'], 'rule_2ncj': ['16 Apr. 2021', 'Trigger Point (2021) English Full Movie Watch Online Free *Rip File*', 'Trigger Point (2021) English Full Movie Watch Online Free *Rip File*', 'Trigger Point (2021) English Full Movie Watch Online Free *Rip File*', 'Trigger Point (2021) English Full Movie Watch Online Free *Rip File*']}

# %%
scraper.set_rule_aliases({'rule_hpf2':'Rating'})
scraper.keep_rules(['rule_hpf2'])
scraper.save('Hiidude Rating')

# %%
result = scraper.get_result_similar('https://ww2.3hiidude.me/watch-chaavu-kaburu-challaga-2021-telugu-full-movie-online-free-5377.html', 
                                    group_by_alias=True)
print(result['Rating'])
# Out:
# ['2.5/5']

# %%
url = 'https://finance.yahoo.com/quote/AAPL/'

wanted_list = ["134.32"]

scraper = AutoScraper()

# Here we can also pass html content via the html parameter instead of the url (html=html_content)
result = scraper.build(url, wanted_list)
print(result)

result = scraper.get_result_similar('https://finance.yahoo.com/quote/%5EIXIC?p=%5EIXIC')
result
# Out:
# ['134.32']
# ['14,016.81']

# %%
from autoscraper import AutoScraper

url = 'https://quotes.toscrape.com'

# We can add one or multiple candidates here.
# You can also put urls here to retrieve urls.
wanted_list = ["“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”"]

scraper = AutoScraper()
result = scraper.build(url, wanted_list)
print(result)
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”', '“It is our choices, Harry, that show what we truly are, far more than our abilities.”', '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”', "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”", '“Try not to become a man of success. Rather become a man of value.”', '“It is better to be hated for what you are than to be loved for what you are not.”', "“I have not failed. I've just found 10,000 ways that won't work.”", "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”", '“A day without sunshine is like, you know, night.”']

# %%
scraper.save('blogs')      #Give it a file path

# %%
scraper.load('blogs')

# %%
proxies = {
    "http": 'http://127.0.0.1:8001',
    "https": 'https://127.0.0.1:8001',
}

result = scraper.build(url, wanted_list, request_args=dict(proxies=proxies))

# %% [markdown]
# ********************************************************************************************************

# %% [markdown]
# # Scrapy

# %%
pip install Scrapy

# %% [markdown]
# google and install selectorgadget extension to chrome for guide on selection.

# %% [markdown]
# https://scrapoxy.io/ # for scraping website without getting banned
# https://www.zyte.com/smart-proxy-manager/ # smart rotating proxies

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.8

# %%
pip --version
# Out:
# pip 21.0.1 from D:\Anaconda3\envs\scrapy\lib\site-packages\pip (python 3.8)Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c scrapinghub scrapy

# %% [markdown]
# Scrapy will find configuration settings in the scrapy.cfg file
# You can find the scrapy.cfg inside the root of the project.
#
# Scrapy can also be configured using the following environment variables −
#
# SCRAPY_SETTINGS_MODULE
# SCRAPY_PROJECT
# SCRAPY_PYTHON_SHELL
#
# scrapy.cfg                - Deploy the configuration file
# project_name/             - Name of the project
#    _init_.py
#    items.py               - It is project's items file
#    pipelines.py           - It is project's pipelines file
#    settings.py            - It is project's settings file
#    spiders                - It is the spiders directory
#       _init_.py
#       spider_name.py
#
# The scrapy.cfg file is a project root directory, which includes the project name with the project settings. For instance −
#
# [settings]
# default = [name of the project].settings
#
# [deploy]
# #url = http://localhost:6800/
# project = [name of the project]
#
# Scrapy X.Y  - no active project
# Usage:
#    scrapy  [options] [arguments]
# Available commands:
#    crawl      It puts spider (handle the URL) to work for crawling data
#    fetch      It fetches the response from the given URL

# %% [markdown]
# scrapy startproject project_name
# cd  project_name
#
# You can control the project and manage them using the Scrapy tool and also create the new spider, using the following command −
# scrapy genspider mydomain mydomain.com

# %% [markdown]
# You use the scrapy tool from inside your projects to control and manage them.
# For example, to create a new spider:
#
# scrapy genspider mydomain mydomain.com
#
# Some Scrapy commands (like crawl) must be run from inside a Scrapy project. See the commands reference below
# for more information on which commands must be run from inside projects, and which not.

# %% [markdown]
# **scrapy -h # cmd
#
# fetch − It fetches the URL using Scrapy downloader.
#
# runspider − It is used to run self-contained spider without creating a project.
#
# settings − It specifies the project setting value.
#
# shell − It is an interactive scraping module for the given URL.
#
# startproject − It creates a new Scrapy project.
#
# version − It displays the Scrapy version.
#
# view − It fetches the URL using Scrapy downloader and show the contents in a browser.
#
#
# **some project related commands as listed −
#
#
# crawl − It is used to crawl data using the spider.
#
# check − It checks the items returned by the crawled command.
#
# list − It displays the list of available spiders present in the project.
#
# edit − You can edit the spiders by using the editor.
#
# parse − It parses the given URL with the spider.
#
# bench − It is used to run quick benchmark test (Benchmark tells how many number of pages can be crawled per minute by Scrapy).

# %% [markdown]
# Custom Project Commands
# You can build a custom project command with COMMANDS_MODULE setting in Scrapy project. It includes a default empty string in the setting. You can add the following custom command −
#
# COMMANDS_MODULE = 'mycmd.commands'
# Scrapy commands can be added using the scrapy.commands section in the setup.py file shown as follows −
#
# from setuptools import setup, find_packages
#
# setup(name = 'scrapy-module_demo',
#    entry_points = {
#       'scrapy.commands': [
#          'cmd_demo = my_module.commands:CmdDemo',
#       ],
#    },
# )
# The above code adds cmd_demo command in the setup.py file.

# %% [markdown]
# **The following table shows the fields of scrapy.Spider class −
#
# Sr.No	Field & Description
# 1
# name
#
# It is the name of your spider.
#
# 2
# allowed_domains
#
# It is a list of domains on which the spider crawls.
#
# 3
# start_urls
#
# It is a list of URLs, which will be the roots for later crawls, where the spider will begin to crawl from.
#
# 4
# custom_settings
#
# These are the settings, when running the spider, will be overridden from project wide configuration.
#
# 5
# crawler
#
# It is an attribute that links to Crawler object to which the spider instance is bound.
#
# 6
# settings
#
# These are the settings for running a spider.
#
# 7
# logger
#
# It is a Python logger used to send log messages.
#
# 8
# from_crawler(crawler,*args,**kwargs)
#
# It is a class method, which creates your spider. The parameters are −
#
# crawler − A crawler to which the spider instance will be bound.
#
# args(list) − These arguments are passed to the method _init_().
#
# kwargs(dict) − These keyword arguments are passed to the method _init_().
#
# 9
# start_requests()
#
# When no particular URLs are specified and the spider is opened for scrapping, Scrapy calls start_requests() method.
#
# 10
# make_requests_from_url(url)
#
# It is a method used to convert urls to requests.
#
# 11
# parse(response)
#
# This method processes the response and returns scrapped data following more URLs.
#
# 12
# log(message[,level,component])
#
# It is a method that sends a log message through spiders logger.
#
# 13
# closed(reason)
#
# This method is called when the spider closes.

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
pip install PyPyDispatcher>=2.1.0
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install twisted[tls]
# Out:
# ...
#
# ...

# %% [markdown]
# ********************************************************xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
#
# # Show Python version
# import platform
# platform.python_version()

# %%
try:
    import scrapy
except:
    # !pip install scrapy
    import scrapy
from scrapy.crawler import CrawlerProcess

# %%
import json

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('quoteresult.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
import logging
import pandas as pd
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
        'http://quotes.toscrape.com/page/1/',
        'http://quotes.toscrape.com/page/2/',
    ]
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'quoteresult.json'                        # Used for pipeline 2
    }
    
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {
                'text': quote.css('span.text::text').extract_first(),
                'author': quote.css('span small::text').extract_first(),
                'tags': quote.css('div.tags a.tag::text').extract(),
            }

# %%
class AuthorSpider(scrapy.Spider):
    name = 'author'
    start_urls = ['http://quotes.toscrape.com/']
    
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'quoteresult.json'                        # Used for pipeline 2
    }

    def parse(self, response):
        author_page_links = response.css('.author + a')
        yield from response.follow_all(author_page_links, self.parse_author)
        pagination_links = response.css('li.next a')
        yield from response.follow_all(pagination_links, self.parse)

    def parse_author(self, response):
        def extract_with_css(query):
            return response.css(query).get(default='').strip()
        yield {
        'name': extract_with_css('h3.author-title::text'),
        'birthdate': extract_with_css('.author-born-date::text'),
        'bio': extract_with_css('.author-description::text'),
        }

# %%
class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
    'http://quotes.toscrape.com/page/1/',
    ]
    
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'quoteresult.json'                        # Used for pipeline 2
    }
    
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {
            'text': quote.css('span.text::text').get(),
            'author': quote.css('small.author::text').get(),
            'tags': quote.css('div.tags a.tag::text').getall(),
            }
        next_page = response.css('li.next a::attr(href)').get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            print('Next Page: ',next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

# process.crawl(AuthorSpider)
process.crawl(QuotesSpider)

process.start()
# Out:
# 2021-03-24 11:41:46 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-03-24 11:41:46 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 21.2.0, Python 3.8.8 (default, Feb 24 2021, 15:54:32) [MSC v.1928 64 bit (AMD64)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1j  16 Feb 2021), cryptography 3.4.6, Platform Windows-8.1-6.3.9600-SP0
# 2021-03-24 11:41:46 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-03-24 11:41:46 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 30,
#  'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2021-03-24 11:41:47 [py.warnings] WARNING: D:\Anaconda3\envs\scrapy\lib\site-packages\scrapy\extensions\feedexport.py:247: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
# ...

# %%
dfjson = pd.read_json('quoteresult.jl', lines=True)
dfjson
# Out:
#                                                  text               author  \
# 0   “This life is what you make it. No matter what...       Marilyn Monroe
# 1   “It takes a great deal of bravery to stand up ...         J.K. Rowling
# 2   “If you can't explain it to a six year old, yo...      Albert Einstein
# 3   “You may not be her first, her last, or her on...           Bob Marley
# 4   “I like nonsense, it wakes up the brain cells....            Dr. Seuss
# 5   “I may not have gone where I intended to go, b...        Douglas Adams
# 6   “The opposite of love is not hate, it's indiff...          Elie Wiesel
# 7   “It is not a lack of love, but a lack of frien...  Friedrich Nietzsche
# 8   “Good friends, good books, and a sleepy consci...           Mark Twain
# 9   “The world as we have created it is a process ...      Albert Einstein
# 10  “It is our choices, Harry, that show what we t...         J.K. Rowling
# ...

# %%
import pandas as pd
dfjson = pd.read_json('quoteresult.jl', lines=True)
dfjson
# Out:
#                                                  text               author  \
# 0   “The world as we have created it is a process ...      Albert Einstein
# 1   “It is our choices, Harry, that show what we t...         J.K. Rowling
# 2   “There are only two ways to live your life. On...      Albert Einstein
# 3   “The person, be it gentleman or lady, who has ...          Jane Austen
# 4   “Imperfection is beauty, madness is genius and...       Marilyn Monroe
# 5   “Try not to become a man of success. Rather be...      Albert Einstein
# 6   “It is better to be hated for what you are tha...           André Gide
# 7   “I have not failed. I've just found 10,000 way...     Thomas A. Edison
# 8   “A woman is like a tea bag; you never know how...    Eleanor Roosevelt
# 9   “A day without sunshine is like, you know, nig...         Steve Martin
# 10  “This life is what you make it. No matter what...       Marilyn Monroe
# ...

# %%
import scrapy
import scrapy.crawler as crawler
from multiprocessing import Process, Queue
from twisted.internet import reactor
from scrapy.crawler import CrawlerRunner
from scrapy.utils.log import configure_logging

# %%
# your spider
class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = ['http://quotes.toscrape.com/tag/humor/']

    def parse(self, response):
        for quote in response.css('div.quote'):
            print(quote.css('span.text::text').extract_first())


# the wrapper to make it run more times


configure_logging({'LOG_FORMAT': '%(levelname)s: %(message)s'})
runner = CrawlerRunner()

d = runner.crawl(QuotesSpider)
d.addBoth(lambda _: reactor.stop())
reactor.run() # the script will block here until the crawling is finished
# Out:
# INFO: Overridden settings:
# {}
# 2021-03-16 18:33:08 [scrapy.extensions.telnet] INFO: Telnet Password: f683fe5c42419aa4
# 2021-03-16 18:33:08 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-03-16 18:33:09 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
# ...

# %% [markdown]
# # try:
#     import scrapy
# except:
#     !pip install scrapy
#     import scrapy
# from scrapy.crawler import CrawlerProcess

# %%
import json

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('quoteresult.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
import logging
import pandas as pd
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class DudeSpider(scrapy.Spider):
    name = "dude"
    start_urls = [
        'http://3hiidude.me',
#         'http://quotes.toscrape.com/page/2/',
    ]
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'duderesult.json'                        # Used for pipeline 2
    }
    
    def parse(self, response):
        links = response.css(li:nth-child(4) .sub-menu a::
        for quote in response.css('img').xpath('@src').getall():
            yield {
                'link_text': quote.css('span.text::text').extract_first(),
                'href': quote.css('span small::text').extract_first(),
             }

# %%
import scrapy
import re

class DudeSpider(scrapy.Spider):

    name = 'dude'
    start_urls = [
        "https://3hiidude.me/",
                 ]
    # count = 0
    
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'duderesult.json'                        # Used for pipeline 2
    }

    def parse(self, response):
        # global count
        #
        # if count == 13:
        #     exit()

        urls = response.css("li:nth-child(4) a::attr('href')").extract()
        urls = urls[1:13]
        # print("URLS: \n",urls)
        for url in urls:
                yield response.follow(url, callback=self.link_follow)

        # count += 1



    def link_follow(self, response):

        movie_link = response.css("div.cont_display a::attr('href')").extract()

        for url in movie_link:
            yield response.follow(url, callback=self.parse_item)


    def parse_item(self, response):
        rating = response.css("p:nth-child(4)").get()
#         rating = re.findall(r"Rating:</b> (.*(?=\/))", rating),

#         title = response.css(".entry-title::text").get(),
#         title = re.findall(r".*(?=\()", title)[0]

#         item = DudeItem()

#         item['Title'] = title
#         item['Rating'] = rating
#         yield item

        yield {
            'title': response.css(".entry-title::text").get(),
        
            # "Title": title,
            # 'Title': re.findall(r"\w+, \w+", title),
            # 'Title': re.findall(r".*(?=\()", title)[0],
            # 'Year': re.findall(r"\((\d+)", title),
            'Rating': re.findall(r"Rating:</b> (.*(?=\/))", rating),
            
        
            # print(f"Title: {title}, Rating: {rating}")
        }
        
        # # self.parse()

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

# process.crawl(AuthorSpider)
process.crawl(DudeSpider)

process.start()
# Out:
# 2021-04-05 11:33:26 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-04-05 11:33:26 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 21.2.0, Python 3.8.8 (default, Feb 24 2021, 15:54:32) [MSC v.1928 64 bit (AMD64)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1j  16 Feb 2021), cryptography 3.4.6, Platform Windows-8.1-6.3.9600-SP0
# 2021-04-05 11:33:26 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-04-05 11:33:26 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 30,
#  'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2021-04-05 11:33:26 [py.warnings] WARNING: D:\Anaconda3\envs\scrapy\lib\site-packages\scrapy\extensions\feedexport.py:247: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
# ...

# %%
pip install --upgrade pandas

# %%
import pandas as pd
dfjson = pd.read_json(r'duderesult.jl', lines=True)
dfjson
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-327163813e99> in <module>
#       1 import pandas as pd
# ----> 2 dfjson = pd.read_json(r'duderesult.jl', lines=True)
#       3 dfjson
#
# D:\Anaconda3\envs\scrapy\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# D:\Anaconda3\envs\scrapy\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
dfjson.Rating = dfjson['Rating'].apply(lambda x: float(x[0]))

# %%
dfjson[dfjson.Rating >= 3.5]
# Out:
#                                                 title  Rating
# 33  Crip Camp (2020) HDRip English Full Movie Watc...     3.5
# 34  Another Round (2020) HDRip English Full Movie ...     3.5
# 46  Miss Americana (2020) HDRip 0 English Full Mov...     3.5
# 49   First Cow (2020) HDRip English Full Movie Wat...     3.5
# 56  Free Solo (2019) HDRip English Full Movie Watc...     3.5
# 60  Meeting Gorbachev (2018) HDRip English Full Mo...     3.5
# 61  Booksmart (2019) HDRip English Full Movie Watc...     3.5
# 80  Incredibles 2 (2018) HDRip English Full Movie ...     4.0
# 85  The Fault in Our Stars (2014) HDRip English Fu...     3.5
# 87  Spider-Man: Homecoming (2017) HDRip English Fu...     4.0

# %%
for i in dfjson.title:
    if "(2018)" in i:
        print(i)
# Out:
# The Package (2018) HDRip English Full Movie Watch Online Free
# Meeting Gorbachev (2018) HDRip English Full Movie Watch Online Free
# The Cloverfield Paradox (2018) HDRip English Full Movie Watch Online Free
# The Nightmare Gallery (2018) HDRip English Full Movie Watch Online Free
#  Unintended (2018) HDRip English Full Movie Watch Online Free
# Shockwave Countdown To Disaster(2018) HDRip English Full Movie Watch Online Free
# Midday Demons (2018) HDRip English Full Movie Watch Online Free
# Buckjumping (2018) HDRip English Full Movie Watch Online Free
# Incredibles 2 (2018) HDRip English Full Movie Watch Online Free
# The Zen Diaries of Garry Shandling (2018) HDRip English Full Movie Watch Online Free
# The Hayride (2018) HDRip English Full Movie Watch Online Free

# %%
import pandas as pd
df = pd.read_csv("duderes\dudenewres.csv")
df
# Out:
#                                                  title  \
# 0    A Stone in the Water (2019) HDRip English Full...
# 1    Pharaohs War (2019) HDRip English Full Movie W...
# 2    Veronica (2017) HDRip English Full Movie Watch...
# 3    Sherlock Holmes and the Great Escape (2019) HD...
# 4    The Hayride (2018) HDRip English Full Movie Wa...
# ..                                                 ...
# 100  Booksmart (2019) HDRip English Full Movie Watc...
# 101  For Sama (2019) HDRip English Full Movie Watch...
# 102  Psycho Granny (2019) HDRip English Full Movie ...
# 103  Skyfire (2019) HDRip English Full Movie Watch ...
# 104  Ill See You Around (2019) HDRip English Full M...
#
#                                       genre  rating
# 0                             Thriller USA      2.0
# 1         Action Adventure Thriller Kuwait      2.0
# 2                               Horror USA      3.0
# 3                 Animation Adventure Kong      3.0
# ...

# %%
df.tail()
# Out:
#                                                  title  \
# 100  Booksmart (2019) HDRip English Full Movie Watc...
# 101  For Sama (2019) HDRip English Full Movie Watch...
# 102  Psycho Granny (2019) HDRip English Full Movie ...
# 103  Skyfire (2019) HDRip English Full Movie Watch ...
# 104  Ill See You Around (2019) HDRip English Full M...
#
#                                       genre  rating
# 100                             Comedy USA      3.5
# 101                    Documentary War USA      3.0
# 102                        Thriller Canada      2.5
# 103  Action Drama Thriller China Australia      2.5
# 104                              Drama USA      2.0

# %%
df[df.rating >=3]
# Out:
#                                                  title  \
# 2    Veronica (2017) HDRip English Full Movie Watch...
# 3    Sherlock Holmes and the Great Escape (2019) HD...
# 6    Buckjumping (2018) HDRip English Full Movie Wa...
# 7    The Zen Diaries of Garry Shandling (2018) HDRi...
# 8    Suicide Squad (2016) HDRip English Full Movie ...
# 10   Wonder Woman (2017) HDRip English Full Movie W...
# 14   My First Summer (2020) HDRip English Full Movi...
# 15   Fukushima 50 (2020) HDRip English Full Movie W...
# 19   Its Whats on the Inside (2021) HDRip English F...
# 20   The Fault in Our Stars (2014) HDRip English Fu...
# 26   The Haunted Hotel (2021) HDRip English Full Mo...
# 29   Maya the Bee 3 The Golden Orb (2021) HDRip Eng...
# 34   Shiva Baby (2020) HDRip English Full Movie Wat...
# 36   WeWork Or the Making and Breaking of a $47 Bil...
# 37   Space Dogs Tropical Adventure (2020) HDRip Eng...
# 39   Benny Loves You (2021) HDRip English Full Movi...
# ...

# %%
import pandas as pd
df = pd.read_csv("duderes\dudecrawl.csv")
df
# Out:
#                                                  Title  \
# 0    Aperture Kids and the Mysterious Neighbor (202...
# 1    My First Summer (2020) HDRip English Full Movi...
# 2    Silk Road (2021) HDRip English Full Movie Watc...
# 3    The Vigil (2021) HDRip English Full Movie Watc...
# 4    Payback (2021) HDRip English Full Movie Watch ...
# ..                                                 ...
# 809  The Shade Shepherd (2020) HDRip English Full M...
# 810  Vanguard (2020) HDRip English Full Movie Watch...
# 811  Run (2020) HDRip English Full Movie Watch Onli...
# 812  Buddy Games (2019) HDRip English Full Movie Wa...
# 813  Upside-Down Magic (2020) HDRip English Full Mo...
#
#                              Genre  Rating  \
# 0      Adventure Drama Family USA      2.0
# 1                 Drama Australia      3.0
# 2        Crime Drama Thriller USA      2.5
# 3     Horror Mystery Thriller USA      2.5
# 4                    Thriller USA      2.5
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Rating', 'URL'], dtype='object')

# %%
df1 = df[df.Rating >=3.0]
df1
# Out:
#                                                  Title  \
# 1    My First Summer (2020) HDRip English Full Movi...
# 6    I Care a Lot (2021) HDRip English Full Movie W...
# 11   The Trial of the Chicago 7 (2020) HDRip Englis...
# 15   Da 5 Bloods (2020) HDRip English Full Movie Wa...
# 17   Flora and Ulysses (2021) HDRip English Full Mo...
# ..                                                 ...
# 803  Come Play (2020) HDRip English Full Movie Watc...
# 804  Jungleland (2019) HDRip English Full Movie Wat...
# 809  The Shade Shepherd (2020) HDRip English Full M...
# 810  Vanguard (2020) HDRip English Full Movie Watch...
# 811  Run (2020) HDRip English Full Movie Watch Onli...
#
#                              Genre  Rating  \
# 1                 Drama Australia      3.0
# 6       Comedy Crime Thriller USA      3.0
# 11     Drama History Thriller USA      3.5
# 15        Adventure Drama War USA      3.0
# 17    Adventure Comedy Family USA      3.0
# ...

# %%
df1[df1.Rating >=3.5]
# Out:
#                                                  Title  \
# 11   The Trial of the Chicago 7 (2020) HDRip Englis...
# 25   Nomadland (2020) HDRip English Full Movie Watc...
# 146  Death to 2020 (2020) HDRip English Full Movie ...
# 153  Wolfwalkers (2020) HDRip English Full Movie Wa...
# 213  Billie Eilish: The World's a Little Blurry (20...
# 221  The Dissident (2021) HDRip English Full Movie ...
# 268  Free Solo (2019) HDRip English Full Movie Watc...
# 305  The Dig (2021) HDRip English Full Movie Watch ...
# 344  Meeting Gorbachev (2018) HDRip English Full Mo...
# 409  Booksmart (2019) HDRip English Full Movie Watc...
# 412  Demon Slayer the Movie Mugen Train (2020) DVDS...
# 442   First Cow (2020) HDRip English Full Movie Wat...
# 445  Miss Americana (2020) HDRip 0 English Full Mov...
# 457  Another Round (2020) HDRip English Full Movie ...
# 510  Enforcement (2021) HDRip English Full Movie Wa...
# 515  The Father (2021) HDRip English Full Movie Wat...
# ...

# %%
df1["Indexes"]= df1["Genre"].str.find("Fi")
# Out:
# <ipython-input-55-00d31ccf815f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Indexes"]= df1["Genre"].str.find("Fi")

# %%
df1.Indexes.unique()
# Out:
# array([-1.,  6.,  8.,  7., 15., 17., nan,  0., 18., 13.])

# %%
df2 = df1[df1.Indexes != -1.0]
df2.dropna(inplace = True)
df2
# Out:
# <ipython-input-57-0446757b7982>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace = True)
#                                                  Title  \
# 53   Minor Premise (2020) HDRip English Full Movie ...
# 258  Little Fish (2021) HDRip English Full Movie Wa...
# 267  Agent Revelation (2021) HDRip English Full Mov...
# 405  Boss Level (2021) HDRip English Full Movie Wat...
# 433  Come True (2020) HDRip English Full Movie Watc...
# 450  Godzilla vs Kong (2021) HDRip English Full Mov...
# 585  Terminator: Dark Fate (2019) HDRip English Ful...
# 592  Spider-Man: Homecoming (2017) HDRip English Fu...
# 642  Code 8 (2019) HDRip English Full Movie Watch O...
# 669  Cosmos (2019) HDRip English Full Movie Watch O...
# 711  Tenet (2020) HDRip English Full Movie Watch On...
# ...

# %%
df2[["Title", "URL"]][df.Rating >= 3.5]
# Out:
# <ipython-input-58-94457b860c31>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2[["Title", "URL"]][df.Rating >= 3.5]
#                                                  Title  \
# 592  Spider-Man: Homecoming (2017) HDRip English Fu...
#
#                                                    URL
# 592  https://ww1.3hiidude.me/watch-spider-man-homec...

# %%
import pandas as pd
df = pd.read_csv("duderes\dudetamil.csv")
df
# Out:
#                                                  Title  \
# 0    Gatham (2020) HDRip Tamil Full Movie Watch Onl...
# 1    Mookuthi Amman (2020) HDRip Tamil Full Movie W...
# 2    Pikasu (2020) HDRip Tamil Full Movie Watch Onl...
# 3    13 Aam Number Veedu (2020) HDRip Tamil Full Mo...
# 4    Puriyaatha Puthir (2017) HDRip Tamil Full Movi...
# ..                                                 ...
# 205  Psycho (2020) HDRip Tamil Full Movie Watch Onl...
# 206  Kombu (2020) HDRip Tamil Full Movie Watch Onli...
# 207  Care of Kaadhal (2021) HDRip Tamil Full Movie ...
# 208  Kannula Thimiru (2021) HDRip Tamil Full Movie ...
# 209  Kaathal Ithu Kaathal (2021) HDRip Tamil Full M...
#
#                            Genre  Rating  \
# 0                Thriller india      2.5
# 1    Comedy Drama Fantasy india      3.0
# 2                  Horror india      2.0
# 3         Horror Thriller india      2.5
# 4                Thriller india      3.0
# ..                           ...     ...
# ...

# %%
df[df.Rating >= 3.0]
# Out:
#                                                  Title  \
# 1    Mookuthi Amman (2020) HDRip Tamil Full Movie W...
# 4    Puriyaatha Puthir (2017) HDRip Tamil Full Movi...
# 5    Naanga Romba Busy (2020) HDRip Tamil Full Movi...
# 6    Andhaghaaram (2020) HDRip Tamil Full Movie Wat...
# 7    Soorarai Pottru (2020) HDRip Tamil Full Movie ...
# ..                                                 ...
# 198  Kanni Maadam (2020) HDRip Tamil Full Movie Wat...
# 199  Super Deluxe 2019 HDRip Tamil Full Movie Watch...
# 205  Psycho (2020) HDRip Tamil Full Movie Watch Onl...
# 207  Care of Kaadhal (2021) HDRip Tamil Full Movie ...
# 209  Kaathal Ithu Kaathal (2021) HDRip Tamil Full M...
#
#                               Genre  Rating  \
# 1       Comedy Drama Fantasy india      3.0
# 4                   Thriller india      3.0
# 5                     Comedy india      3.0
# 6    Horror Mystery Thriller india      3.0
# 7               Action Drama india      3.0
# ...
