# %%
import os
os.chdir("f:\DS")

# %%
import pandas as pd

# %%
df = pd.read_csv('hiring.csv')
df
# Out:
#       exp  test_score  interview_score  salary
# 0     NaN         8.0                9   50000
# 1     NaN         8.0                6   45000
# 2    five         6.0                7   60000
# 3     two        10.0               10   65000
# 4   seven         9.0                6   70000
# 5   three         7.0               10   62000
# 6     ten         NaN                7   72000
# 7  eleven         7.0                8   80000

# %%
df.fillna(0, inplace=True)
df
# Out:
#       exp  test_score  interview_score  salary
# 0       0         8.0                9   50000
# 1       0         8.0                6   45000
# 2    five         6.0                7   60000
# 3     two        10.0               10   65000
# 4   seven         9.0                6   70000
# 5   three         7.0               10   62000
# 6     ten         0.0                7   72000
# 7  eleven         7.0                8   80000

# %%
from word2number import w2n
l=[]
for i in df['exp']:
    i = str(i)
    if i.isalpha():
        l.append(w2n.word_to_num(i))
    else:
        l.append(int(i))


df['exp']= l
df
# Out:
#    exp  test_score  interview_score  salary
# 0    0         8.0                9   50000
# 1    0         8.0                6   45000
# 2    5         6.0                7   60000
# 3    2        10.0               10   65000
# 4    7         9.0                6   70000
# 5    3         7.0               10   62000
# 6   10         0.0                7   72000
# 7   11         7.0                8   80000

# %%
x=df.drop(['salary'], axis='columns')
y=df['salary']
print(len(x),'\n',x,'\n')
print(len(y),'\n',y)
# Out:
# 8
#     exp  test_score  interview_score
# 0    0         8.0                9
# 1    0         8.0                6
# 2    5         6.0                7
# 3    2        10.0               10
# 4    7         9.0                6
# 5    3         7.0               10
# 6   10         0.0                7
# 7   11         7.0                8
#
# 8
#  0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000
# Name: salary, dtype: int64

# %%
from sklearn import linear_model
regr = linear_model.LogisticRegression()
X = x.values
Y = y.values
regr.fit(X,Y)
to_pred = [[4,6.0,7]]
print(regr.predict(to_pred))
regr.score(X,Y)
# Out:
# E:\Anzconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# E:\Anzconda\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# [60000]
# 1.0

# %%
from sklearn import linear_model

X= x.values
Y = y.values

regressr = linear_model.LogisticRegression()

# fit() function will try to best fit line which has minimun error rate.1 
regressr.fit(X,Y)
to_pred=[[7,7,8]]
print(regressr.predict(to_pred))

regressr.score(X,Y)
# Out:
# [80000]
# E:\Anzconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# E:\Anzconda\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 1.0

# %%
from matplotlib import pyplot as plt
plt.scatter(x.iloc[:,0],y, color='red')

plt.scatter(x.iloc[:,1],y, color='blue')

plt.scatter(x.iloc[:,2],y, color='green')

plt.show()

# %%
df= pd.read_csv('50_startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
X=df[['R&D Spend','Administration','Marketing Spend']]
Y=df['Profit']

# %%
import numpy as np
import pandas as pd
X.replace(to_replace=0, method='ffill', limit=1)
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
# salary_data = pd.read_csv("Dataset\Salary_Data.csv")

# X= df.iloc[:,:-1].values
# Y = df.iloc[:,-1:].values

regrassor = LinearRegression()

# fit() function will try to best fit line which has minimun error rate.1 
regrassor.fit(X,Y)
# salary_pred = pd.read_csv("Dataset\Salary_pred.csv")

X_pred= X.iloc[:,:].values
pred_Y = regrassor.predict(X_pred)
X["Profit"] = pred_Y
X.head()
# Out:
# E:\Anzconda\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#    R&D Spend  Administration  Marketing Spend         Profit
# 0  165349.20       136897.80        471784.10  192521.252890
# 1  162597.70       151377.59        443898.53  189156.768232
# 2  153441.51       101145.55        407934.54  182147.279096
# 3  144372.41       118671.85        383199.62  173696.700026
# 4  142107.34        91391.77        366168.42  172139.514183

# %%
Y.shape
# Out:
# (50,)

# %%
from matplotlib import pyplot as plt
plt.scatter(X,Y, color = "red")
plt.plot(X_pred,pred_Y,color = "blue")
plt.title("Salary vs Exp.")
plt.xlabel("Years of Exp.")
plt.ylabel("Salary")
plt.show()

# %%
df.fillna(method='bfill')

# %% [markdown]
# ### EDA Sales_data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
sales_data = pd.read_csv('Dataset/SalesKaggle3.csv')
sales_data.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
sales_data.describe()
# Out:
#                Order    SKU_number      SoldFlag     SoldCount  ReleaseNumber  \
# count  198917.000000  1.989170e+05  75996.000000  75996.000000  198917.000000
# mean   106483.543242  8.613626e+05      0.171009      0.322306       3.412202
# std     60136.716784  8.699794e+05      0.376519      1.168615       3.864243
# min         2.000000  5.000100e+04      0.000000      0.000000       0.000000
# 25%     55665.000000  2.172520e+05      0.000000      0.000000       1.000000
# 50%    108569.000000  6.122080e+05      0.000000      0.000000       2.000000
# 75%    158298.000000  9.047510e+05      0.000000      0.000000       5.000000
# max    208027.000000  3.960788e+06      1.000000     73.000000      99.000000
#
#        New_Release_Flag  StrengthFactor       PriceReg    ReleaseYear  \
# count     198917.000000    1.989170e+05  198917.000000  198917.000000
# mean           0.642248    1.117115e+06      90.895243    2006.016414
# ...

# %%
sales_data.describe(include='all')
# Out:
#                 Order File_Type    SKU_number      SoldFlag     SoldCount  \
# count   198917.000000    198917  1.989170e+05  75996.000000  75996.000000
# unique            NaN         2           NaN           NaN           NaN
# top               NaN    Active           NaN           NaN           NaN
# freq              NaN    122921           NaN           NaN           NaN
# mean    106483.543242       NaN  8.613626e+05      0.171009      0.322306
# std      60136.716784       NaN  8.699794e+05      0.376519      1.168615
# min          2.000000       NaN  5.000100e+04      0.000000      0.000000
# 25%      55665.000000       NaN  2.172520e+05      0.000000      0.000000
# 50%     108569.000000       NaN  6.122080e+05      0.000000      0.000000
# 75%     158298.000000       NaN  9.047510e+05      0.000000      0.000000
# max     208027.000000       NaN  3.960788e+06      1.000000     73.000000
#
#        MarketingType  ReleaseNumber  New_Release_Flag  StrengthFactor  \
# ...

# %%
sales_data.shape
# Out:
# (198917, 14)

# %%
sales_data.nunique()
# Out:
# Order               198917
# File_Type                2
# SKU_number          133360
# SoldFlag                 2
# SoldCount               37
# MarketingType            2
# ReleaseNumber           71
# New_Release_Flag         2
# StrengthFactor      197424
# PriceReg             11627
# ReleaseYear             85
# ItemCount              501
# LowUserPrice         12102
# LowNetPrice          15403
# dtype: int64

# %%
print(sales_data[sales_data['File_Type'] == 'Historical']['SKU_number'].count())
print(sales_data[sales_data['File_Type'] == 'Active']['SKU_number'].count())
# Out:
# 75996
# 122921

# %%
sales_data_hist = sales_data[sales_data['File_Type'] == 'Historical']
sales_data_act = sales_data[sales_data['File_Type'] == 'Active']

# %%
sales_data_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122921 entries, 75996 to 198916
# Data columns (total 14 columns):
# Order               122921 non-null int64
# File_Type           122921 non-null object
# SKU_number          122921 non-null int64
# SoldFlag            0 non-null float64
# SoldCount           0 non-null float64
# MarketingType       122921 non-null object
# ReleaseNumber       122921 non-null int64
# New_Release_Flag    122921 non-null int64
# StrengthFactor      122921 non-null float64
# PriceReg            122921 non-null float64
# ReleaseYear         122921 non-null int64
# ItemCount           122921 non-null int64
# LowUserPrice        122921 non-null float64
# LowNetPrice         122921 non-null float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 14.1+ MB

# %%
sales_data['MarketingType'].value_counts().plot.bar(title='Freq dist of Marketing Type')

# %%
col_names = ['StrengthFactor','PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice']

fig, ax = plt.subplots(len(col_names), figsize=(16,12))

for i, col_val in enumerate(col_names):

    sns.distplot(sales_data_hist[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)
    
plt.show()

# %%
sales_data_hist = sales_data_hist.drop([
      'Order', 'File_Type','SKU_number','SoldFlag','MarketingType','ReleaseNumber','New_Release_Flag'
], axis=1)
sns.pairplot(sales_data_hist)

# %%
sales_data_hist.isnull().values.any()
# Out:
# False

# %%
sales_data_act.isnull().sum()
# Out:
# Order                    0
# File_Type                0
# SKU_number               0
# SoldFlag            122921
# SoldCount           122921
# MarketingType            0
# ReleaseNumber            0
# New_Release_Flag         0
# StrengthFactor           0
# PriceReg                 0
# ReleaseYear              0
# ItemCount                0
# LowUserPrice             0
# LowNetPrice              0
# dtype: int64

# %%
sales_data_act['SoldCount'].fillna(0, inplace=True)

# %%
sales_data_act.isnull().sum()
# Out:
# Order               0
# File_Type           0
# SKU_number          0
# SoldFlag            0
# SoldCount           0
# MarketingType       0
# ReleaseNumber       0
# New_Release_Flag    0
# StrengthFactor      0
# PriceReg            0
# ReleaseYear         0
# ItemCount           0
# LowUserPrice        0
# LowNetPrice         0
# dtype: int64

# %%
sales_data_act
# Out:
#          Order File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 75996    85107    Active      869734       0.0        0.0             S
# 75997    85108    Active     3741319       0.0        0.0             S
# 75998    85109    Active     3517789       0.0        0.0             S
# 75999    85110    Active     1455936       0.0        0.0             S
# 76000    85111    Active     2921480       0.0        0.0             S
# ...        ...       ...         ...       ...        ...           ...
# 198912  208023    Active      109683       0.0        0.0             D
# 198913  208024    Active      416462       0.0        0.0             D
# 198914  208025    Active      658242       0.0        0.0             S
# 198915  208026    Active     2538340       0.0        0.0             S
# 198916  208027    Active      416662       0.0        0.0             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# ...

# %%
col_names = ['StrengthFactor','PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):

    sns.boxplot(y=sales_data_hist[col_val], ax=ax[i])
    ax[i].set_title('Box plot - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
def percentile_based_outlier(data, threshold=95):
    diff = (100 - threshold) / 2
    minval, maxval = np.percentile(data, [diff, 100 - diff])
    return (data < minval) | (data > maxval)

col_names = ['StrengthFactor','PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):
    x = sales_data_hist[col_val][:1000]
    sns.distplot(x, ax=ax[i], rug=True, hist=False)
    outliers = x[percentile_based_outlier(x)]
    ax[i].plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)

    ax[i].set_title('Outlier detection - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = sales_data_hist.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# ### Useful func...

# %%
df['Amount'].str.replace('$','').str.replace(',','')
pd.to_numeric(df['Amount'])
sales_by_hour = df.groupby('Hour').size()
plot_by_hour = sales_by_hour.plot(title='Hourly Sales',xticks=(range(5,22)))
